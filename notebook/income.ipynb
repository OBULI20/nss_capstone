# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('../data/us_final.xlsx',sheet_name='median income')
df
# Out:
#    State_code                  name   2013   2014   2015   2016    2017  \
# 0          AK                Alaska  92270  84900  94360  94290   95440
# 1          AL               Alabama  60250  53070  55920  58800   62250
# 2          AR              Arkansas  50130  56390  53770  57170   60880
# 3          AZ               Arizona  66980  61830  65640  71100   73060
# 4          CA            California  77400  75930  79940  82980   85710
# 5          CO              Colorado  86470  76500  83660  87870   91760
# 6          CT           Connecticut  88220  88080  91570  94540   90930
# 7          DC  District of Columbia  76460  85710  88030  88390   99470
# 8          DE              Delaware  68870  72210  72560  72280   79500
# 9          FL               Florida  61790  57920  61340  63730   64960
# 10         GA               Georgia  59830  62210  63780  66650   70960
# 11         HI                Hawaii  81780  89410  81050  89820   90070
# ...

# %%
df.columns
# Out:
# Index(['State_code',       'name',         2013,         2014,         2015,
#                2016,         2017,         2018,         2019,         2020,
#                2021,         2022,         2023],
#       dtype='object')

# %%
df1=df[['State_code','name',2013]]
df1['year']='2013'
df1=df1.rename(columns={2013:'income'})
df1
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\2376848825.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['year']='2013'
#    State_code                  name  income  year
# 0          AK                Alaska   92270  2013
# 1          AL               Alabama   60250  2013
# 2          AR              Arkansas   50130  2013
# 3          AZ               Arizona   66980  2013
# 4          CA            California   77400  2013
# 5          CO              Colorado   86470  2013
# 6          CT           Connecticut   88220  2013
# 7          DC  District of Columbia   76460  2013
# 8          DE              Delaware   68870  2013
# 9          FL               Florida   61790  2013
# ...

# %%
df2=df[['State_code','name',2014]]
df2['year']='2014'
df2=df2.rename(columns={2014:'income'})
df2
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\2527360507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year']='2014'
#    State_code                  name  income  year
# 0          AK                Alaska   84900  2014
# 1          AL               Alabama   53070  2014
# 2          AR              Arkansas   56390  2014
# 3          AZ               Arizona   61830  2014
# 4          CA            California   75930  2014
# 5          CO              Colorado   76500  2014
# 6          CT           Connecticut   88080  2014
# 7          DC  District of Columbia   85710  2014
# 8          DE              Delaware   72210  2014
# 9          FL               Florida   57920  2014
# ...

# %%
main=pd.concat([df1,df2])
main
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 main=pd.concat([df1,df2],on=['name','year'])
#       2 main
#
# TypeError: concat() got an unexpected keyword argument 'on'

# %%
df3=df[['State_code','name',2015]]
df3['year']='2015'
df3=df3.rename(columns={2015:'income'})
df3
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\1581930510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['year']='2015'
#    State_code                  name  income  year
# 0          AK                Alaska   94360  2015
# 1          AL               Alabama   55920  2015
# 2          AR              Arkansas   53770  2015
# 3          AZ               Arizona   65640  2015
# 4          CA            California   79940  2015
# 5          CO              Colorado   83660  2015
# 6          CT           Connecticut   91570  2015
# 7          DC  District of Columbia   88030  2015
# 8          DE              Delaware   72560  2015
# 9          FL               Florida   61340  2015
# ...

# %%
main=pd.concat([main,df3])
main
# Out:
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   74740  2015
# 47         WA     Washington   84480  2015
# 48         WV  West Virginia   53800  2015
# 49         WI      Wisconsin   69630  2015
# 50         WY        Wyoming   76540  2015
#
# [153 rows x 4 columns]

# %%
df4=df[['State_code','name',2016]]
df4['year']='2016'
df4=df4.rename(columns={2016:'income'})
df4

main=pd.concat([main,df4])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\4200009122.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['year']='2016'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   75760  2016
# 47         WA     Washington   87550  2016
# 48         WV  West Virginia   55230  2016
# 49         WI      Wisconsin   74490  2016
# 50         WY        Wyoming   72010  2016
#
# [204 rows x 4 columns]

# %%
df5=df[['State_code','name',2017]]
df5['year']='2017'
df5=df5.rename(columns={2017:'income'})
df5

main=pd.concat([main,df5])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\2060603045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['year']='2017'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   77930  2017
# 47         WA     Washington   87550  2017
# 48         WV  West Virginia   57460  2017
# 49         WI      Wisconsin   77690  2017
# 50         WY        Wyoming   72860  2017
#
# [255 rows x 4 columns]

# %%
df6=df[['State_code','name',2018]]
df6['year']='2018'
df6=df6.rename(columns={2018:'income'})
df6

main=pd.concat([main,df6])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\2664301415.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['year']='2018'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   84050  2018
# 47         WA     Washington   95640  2018
# 48         WV  West Virginia   60670  2018
# 49         WI      Wisconsin   75130  2018
# 50         WY        Wyoming   75020  2018
#
# [306 rows x 4 columns]

# %%
df7=df[['State_code','name',2019]]
df7['year']='2019'
df7=df7.rename(columns={2019:'income'})
df7

main=pd.concat([main,df7])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\2101261101.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['year']='2019'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   87830  2019
# 47         WA     Washington   97470  2019
# 48         WV  West Virginia   63480  2019
# 49         WI      Wisconsin   79620  2019
# 50         WY        Wyoming   76990  2019
#
# [357 rows x 4 columns]

# %%
df8=df[['State_code','name',2020]]
df8['year']='2020'
df8=df8.rename(columns={2020:'income'})
df8

main=pd.concat([main,df8])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\3514182731.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8['year']='2020'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   78680  2020
# 47         WA     Washington   95180  2020
# 48         WV  West Virginia   60800  2020
# 49         WI      Wisconsin   78860  2020
# 50         WY        Wyoming   76570  2020
#
# [408 rows x 4 columns]

# %%
df9=df[['State_code','name',2021]]
df9['year']='2021'
df9=df9.rename(columns={2021:'income'})
df9

main=pd.concat([main,df9])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\3871255127.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df9['year']='2021'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   85190  2021
# 47         WA     Washington   98150  2021
# 48         WV  West Virginia   52450  2021
# 49         WI      Wisconsin   78320  2021
# 50         WY        Wyoming   79570  2021
#
# [459 rows x 4 columns]

# %%
df10=df[['State_code','name',2022]]
df10['year']='2022'
df10=df10.rename(columns={2022:'income'})
df10

main=pd.concat([main,df10])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\914017607.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10['year']='2022'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   75060  2022
# 47         WA     Washington   92980  2022
# 48         WV  West Virginia   54540  2022
# 49         WI      Wisconsin   76240  2022
# 50         WY        Wyoming   76000  2022
#
# [510 rows x 4 columns]

# %%
df11=df[['State_code','name',2023]]
df11['year']='2023'
df11=df11.rename(columns={2023:'income'})
df11
main=pd.concat([main,df11])
main
# Out:
# C:\Users\obuli\AppData\Local\Temp\ipykernel_48268\4199397771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df11['year']='2023'
#    State_code           name  income  year
# 0          AK         Alaska   92270  2013
# 1          AL        Alabama   60250  2013
# 2          AR       Arkansas   50130  2013
# 3          AZ        Arizona   66980  2013
# 4          CA     California   77400  2013
# ..        ...            ...     ...   ...
# 46         VT        Vermont   85190  2023
# 47         WA     Washington   93440  2023
# 48         WV  West Virginia   60410  2023
# 49         WI      Wisconsin   79690  2023
# 50         WY        Wyoming   77200  2023
#
# [561 rows x 4 columns]

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 561 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State_code  561 non-null    object
#  1   name        561 non-null    object
#  2   income      561 non-null    int64
#  3   year        561 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 21.9+ KB

# %%
main.year=main.year.astype(int)

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 561 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State_code  561 non-null    object
#  1   name        561 non-null    object
#  2   income      561 non-null    int64
#  3   year        561 non-null    int32
# dtypes: int32(1), int64(1), object(2)
# memory usage: 19.7+ KB

# %%
main.to_excel('income.xlsx',sheet_name='income')
